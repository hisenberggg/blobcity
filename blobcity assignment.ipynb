# %%
import pandas as pd
import warnings
import numpy as np
from sklearn.preprocessing import LabelEncoder,OrdinalEncoder,StandardScaler,MinMaxScaler,RobustScaler,normalize,scale
warnings.filterwarnings("ignore")

# %%
df= pd.read_csv(r"C:\Users\Dell\dataset/train.csv")
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
mean_value = df['LoanAmount'].median()

# %%
df['LoanAmount'].fillna(value=mean_value, inplace=True)

# %%
df['LoanAmount'].values
# Out:
# array([128., 128.,  66., 120., 141., 267.,  95., 158., 168., 349.,  70.,
#        109., 200., 114.,  17., 125., 100.,  76., 133., 115., 104., 315.,
#        116., 112., 151., 191., 122., 110.,  35., 120., 201.,  74., 106.,
#        114., 320., 128., 100., 144., 184., 110.,  80.,  47.,  75., 134.,
#         96.,  88.,  44., 144., 120., 144., 100., 120., 112., 134., 286.,
#         97.,  96., 135., 180., 144., 120.,  99., 165., 128., 116., 258.,
#        126., 312., 125., 136., 172.,  97.,  81.,  95., 187., 113., 176.,
#        110., 180., 130., 111., 128., 167., 265.,  50., 136.,  99., 104.,
#        210., 175., 131., 188.,  81., 122.,  25., 128., 137.,  50., 115.,
#        131., 133., 151., 128., 128., 160., 100., 225., 120., 216.,  94.,
#        136., 139., 152., 128., 118., 185., 154.,  85., 175., 259., 180.,
#         44., 137.,  81., 194.,  93., 370., 128., 160., 182., 650.,  74.,
#         70.,  25., 102., 290.,  84.,  88., 242., 129., 185., 168., 175.,
# ...

# %%
# df['Gender']=np.where(df['Gender']=='Male',1,0)
# df['Gender']=LabelEncoder().fit_transform(df['Gender'])
# df['Gender'] = OrdinalEncoder().fit_transform(df['Gender'].values.reshape(-1, 1))
#all satisfy
print(df['Gender'])
# Out:
# 0      1.0
# 1      1.0
# 2      1.0
# 3      1.0
# 4      1.0
#       ...
# 609    0.0
# 610    1.0
# 611    1.0
# 612    1.0
# 613    0.0
# Name: Gender, Length: 614, dtype: float64

# %%
max_avg=df[["Property_Area","LoanAmount"]]
max_avg
# Out:
#     Property_Area  LoanAmount
# 0           Urban       128.0
# 1           Rural       128.0
# 2           Urban        66.0
# 3           Urban       120.0
# 4           Urban       141.0
# ..            ...         ...
# 609         Rural        71.0
# 610         Rural        40.0
# 611         Urban       253.0
# 612         Urban       187.0
# 613     Semiurban       133.0
#
# [614 rows x 2 columns]

# %%
max_avg.groupby(['Property_Area']).mean()
# Out:
#                LoanAmount
# Property_Area
# Rural          151.446927
# Semiurban      145.128755
# Urban          141.425743

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002     1.0      No          0      Graduate            No
# 1    LP001003     1.0     Yes          1      Graduate            No
# 2    LP001005     1.0     Yes          0      Graduate           Yes
# 3    LP001006     1.0     Yes          0  Not Graduate            No
# 4    LP001008     1.0      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978     0.0      No          0      Graduate            No
# 610  LP002979     1.0     Yes         3+      Graduate            No
# 611  LP002983     1.0     Yes          1      Graduate            No
# 612  LP002984     1.0     Yes          2      Graduate            No
# 613  LP002990     0.0      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
total_income=df["ApplicantIncome"]+df["CoapplicantIncome"]
total_income
# Out:
# 0      5849.0
# 1      6091.0
# 2      3000.0
# 3      4941.0
# 4      6000.0
#         ...
# 609    2900.0
# 610    4106.0
# 611    8312.0
# 612    7583.0
# 613    4583.0
# Length: 614, dtype: float64

# %%
df.insert(8, "total_income", total_income, True)
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  total_income  LoanAmount  \
# 0               5849                0.0        5849.0         NaN
# ...

# %%
avg_totalincome = df[["Education","total_income"]]

# %%
avg_totalincome.groupby(["Education"]).mean()
# Out:
#               total_income
# Education
# Graduate       7574.908167
# Not Graduate   5053.828358

# %%
df= pd.read_csv(r"C:\Users\Dell\dataset/train.csv")
rescaling = df[["ApplicantIncome","CoapplicantIncome"]]

# op = StandardScaler().fit_transform(rescaling.values)
op = MinMaxScaler().fit_transform(rescaling.values)
# op = RobustScaler().fit_transform(rescaling.values)
# op = normalize(rescaling.values,norm='l2')
# op = scale(rescaling.values)

# %%
op
# Out:
# array([[0.07048856, 0.        ],
#        [0.05482993, 0.03619171],
#        [0.03525046, 0.        ],
#        ...,
#        [0.09798392, 0.00575995],
#        [0.09193568, 0.        ],
#        [0.05482993, 0.        ]])
